# %% [markdown]
# <a href="https://colab.research.google.com/github/thangarani/project/blob/master/pegasus_extractive_vs_abstractive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pegasus - Extractive Vs Abstractive Summarization
#
# ---

# %% [markdown]
# Text summarization is the task of shortening a given text yet retaining the essential gist of the entire document. Summarization is usually seen to be broadly divided into two categories Extractive and Abstractive.
#
# **Extractive** summarization can be seen as the task of ranking and scoring sentences in the document based on certain metrics and then picking top-k sentences as the representative summary of the input the document, whereas,
#
# **Abstractive** summarization can be seen as a technique in which the summary is generated by generating novel sentences by either rephrasing or using the new words, instead of simply extracting the important sentences generating a summary of the input document yet retaining the main essence of the document and being linguistically correct at the same time..

# %% [markdown]
# Clone [Pegasus-demo](https://github.com/TheRockXu/pegasus-demo.git) project

# %%
# !git clone https://github.com/TheRockXu/pegasus-demo.git
# Out:
# Cloning into 'pegasus-demo'...
# remote: Enumerating objects: 230, done.
# remote: Total 230 (delta 0), reused 0 (delta 0), pack-reused 230
# Receiving objects: 100% (230/230), 1.86 MiB | 537.00 KiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
cd /content/pegasus-demo
# Out:
# /content/pegasus-demo

# %%
mkdir model
# Out:
# mkdir: cannot create directory ‘model’: File exists

# %%
cd /content/pegasus-demo/model/

# %% [markdown]
# Pretrained Model
#
# ---

# %% [markdown]
# I uploaded the pretrained model to my Google drive, so i am doing copy and paste from there. For you, please download the pretrained cnn_dailymail and gigaword model directly from https://drive.google.com/file/d/1FVzZto4bf5_TCmRy3tNeirhPDdLrvum5/view and https://drive.google.com/file/d/1ZF2qO6bAnsTF2LSndLMir3e7NrlFL288/view respectively. Unzip it and put it to model/

# %%
cp /content/drive/My\ Drive/Colab\ Notebooks/gigaword.tar.xz .

# %%
cp /content/drive/My\ Drive/Colab\ Notebooks/cnn_dailymail.xz .

# %% [markdown]
# Install sentence piece

# %%
# !pip install sentencepiece

# %% [markdown]
# Install xz-utils unzip

# %%
# !sudo apt install xz-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# xz-utils is already the newest version (5.2.2-1.3).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
cd /content/pegasus-demo/model/
# Out:
# /content/pegasus-demo/model

# %%
ls
# Out:
# 1595095633/  cnn_dailymail.xz  gigaword.tar.xz

# %% [markdown]
# # ***Extractive Summarization***
#
# ---
#
#
#
# ---

# %% [markdown]
# Cnn_Dailymail
# ---

# %%
# !tar -xvf cnn_dailymail.xz
# Out:
# 1595037231/
# 1595037231/saved_model.pb
# 1595037231/variables/
# 1595037231/variables/variables.data-00000-of-00001
# 1595037231/variables/variables.index

# %%
cd /content/pegasus-demo
# Out:
# /content/pegasus-demo

# %% [markdown]
# Example
#
# ---

# %%
# !python test_example.py --article example_article --model_dir /content/pegasus-demo/model/1595037231/ --model_name cnn_dailymail
# Out:
# 2020-08-05 08:19:20.047703: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-05 08:19:25.002159: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-08-05 08:19:25.069711: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-08-05 08:19:25.069804: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (a5c8dd530367): /proc/driver/nvidia/version does not exist
# 2020-08-05 08:19:25.129665: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-08-05 08:19:25.130056: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2b5aa00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# # ***Abstractive Summarization***
# ---
#
#
#
# ---

# %% [markdown]
# # Gigaword

# %%
# !tar -xvf gigaword.tar.xz
# Out:
# 1595095633/
# 1595095633/saved_model.pb
# 1595095633/variables/
# 1595095633/variables/variables.data-00000-of-00001
# 1595095633/variables/variables.index

# %%
cd /content/pegasus-demo
# Out:
# /content/pegasus-demo

# %% [markdown]
# Example
#
# ---

# %%
# !python test_example.py --article example_article --model_dir /content/pegasus-demo/model/1595095633/ --model_name gigaword
# Out:
# 2020-08-05 08:08:16.504598: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-05 08:08:20.862217: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-08-05 08:08:20.967088: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-08-05 08:08:20.967197: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (a5c8dd530367): /proc/driver/nvidia/version does not exist
# 2020-08-05 08:08:21.036173: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-08-05 08:08:21.036675: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2482a00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# ...

# %% [markdown]
# Reference:
# https://github.com/google-research/pegasus/issues/13 , https://github.com/google-research/pegasus/issues/63
